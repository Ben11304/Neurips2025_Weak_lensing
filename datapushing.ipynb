# %%
from kaggle.api.kaggle_api_extended import KaggleApi
import os

# Initialize the API (authenticates using kaggle.json)
api = KaggleApi()
api.authenticate()

# Path to your dataset folder
dataset_path = '/Users/viethuy/Working_space/Neurips/Neurips2025_Weak_lensing/dataset'

# Create a new dataset
api.dataset_create_new(folder=dataset_path)

# To update an existing dataset (specify the dataset slug like 'yourusername/my-dataset-slug')
# api.dataset_version(dataset='viethuyduong/neurips-dts', dir_name=dataset_path, message='Updated dataset')
# Out:
# Starting upload for file kappa_noisy_chunk_20.npy
# 100%|██████████| 1.89G/1.89G [01:21<00:00, 24.9MB/s]
# Upload successful: kappa_noisy_chunk_20.npy (2GB)
# Starting upload for file kappa_noisy_chunk_21.npy
# 100%|██████████| 1.89G/1.89G [01:22<00:00, 24.6MB/s]
# Upload successful: kappa_noisy_chunk_21.npy (2GB)
# Starting upload for file kappa_noisy_chunk_23.npy
# 100%|██████████| 1.89G/1.89G [00:51<00:00, 39.2MB/s]
# Upload successful: kappa_noisy_chunk_23.npy (2GB)
# Starting upload for file kappa_noisy_chunk_22.npy
# 100%|██████████| 1.89G/1.89G [00:54<00:00, 37.3MB/s]
# Upload successful: kappa_noisy_chunk_22.npy (2GB)
# Starting upload for file kappa_noisy_chunk_8.npy
# 100%|██████████| 1.89G/1.89G [00:47<00:00, 42.8MB/s]
# Upload successful: kappa_noisy_chunk_8.npy (2GB)
# Starting upload for file .DS_Store
# 100%|██████████| 6.00k/6.00k [00:00<00:00, 17.4kB/s]
# Upload successful: .DS_Store (6KB)
# Starting upload for file kappa_noisy_chunk_9.npy
# ...
